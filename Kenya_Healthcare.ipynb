# %% [markdown]
# #Enhancing Healthcare Accessibility in Nairobi, Kenya

# %%
#import libraries to be used
import warnings

import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

pd.set_option('display.max_columns', None)

warnings.filterwarnings("ignore")

# %% [markdown]
# ##Data Set to be used

# %%
#import link for Health care services
link_health_centres="https://open.africa/dataset/3e95b5cb-39f5-44d3-94b6-f2d5285b0478/resource/0257f153-7228-49ef-b330-8e8ed3c7c7e8/download/ehealth-kenya-facilities-download-21102015.xls"
#import population lik
people="https://open.africa/dataset/9b94fe50-9d75-4b92-be00-6354c6e6cc88/resource/f1fca3c3-af10-4b55-b33a-95e8fbbd8dc2/download/kenya-population-by-sub-county.csv"
#import human-waste-disposal data
waste_link="https://open.africa/dataset/9b94fe50-9d75-4b92-be00-6354c6e6cc88/resource/8ea5c765-5de9-4b71-9454-8471cd841b6b/download/percentage-distribution-of-conventional-households-by-main-mode-of-human-waste-disposal-county-a.csv"
#import water source Link
water_link="https://open.africa/dataset/9b94fe50-9d75-4b92-be00-6354c6e6cc88/resource/ea9263c3-3c48-4b23-9a79-b175945e690e/download/percentage-distribution-of-conventional-households-by-main-source-of-drinking-water-county-and-s.csv"

# %% [markdown]
# ### Demographic data

# %%
df_people=pd.read_csv(people, skiprows=6, usecols=range(5))
#remove white spaces
df_people.name=df_people.name.str.strip().str.upper()
df_people['name']= np.where(df_people['name'].str.contains("LANG'ATA"), "LANGATA", df_people['name'])
#df_people['Sub_County']=df_people['name']
df_people.tail(10)
# Out:
#           name    Male  Female  Intersex   Total
# 383   EMBAKASI  492476  496270      62.0  988808
# 384  KAMUKUNJI  136670  131599       7.0  268276
# 385   KASARANI  381234  399385      37.0  780656
# 386      KIBRA   94199   91569       9.0  185777
# 387    LANGATA   96698  100774      17.0  197489
# 388   MAKADARA   96369   93157      10.0  189536
# 389    MATHARE  106522  100028      14.0  206564
# 390      NJIRU  307642  318809      31.0  626482
# 391    STAREHE  109173  101238      12.0  210423
# 392  WESTLANDS  153818  155021      15.0  308854

# %%
df_people['name'].value_counts()
# Out:
# name
# MT. KENYA FORES T*    5
# WEST POKOT            2
# TANA RIVER            2
# VIHIGA                2
# MACHAKOS              2
#                      ..
# KATHONZWENI           1
# YATTA                 1
# MWALA                 1
# MATUNGULU             1
# WESTLANDS             1
# Name: count, Length: 378, dtype: int64

# %% [markdown]
# ### Main Source of drinking Water Data

# %%
df_water=pd.read_csv(water_link)
df_water.drop(columns=['Conventional Households'], inplace=True)
df_water.tail(10)
# Out:
#     County/ Sub-County  Pond Dam/ Lake  Stream/ River  Protected Spring  \
# 386          KAMUKUNJI   0.0       0.6            0.0               0.2
# 387           KASARANI   0.0       0.1            0.0               0.5
# 388              KIBRA   0.0       0.0            0.0               1.4
# 389            LANGATA   0.2       0.2            0.0               0.2
# 390           MAKADARA   0.0       0.2            0.1               0.1
# 391            MATHARE   0.0       0.0            0.0               0.3
# 392              NJIRU   0.0       0.1            0.0               0.4
# 393            STAREHE   0.0       0.2            0.0               0.5
# 394          WESTLANDS   0.0       0.2            0.1               1.1
# 395                NaN   NaN       NaN            NaN               NaN
#
#      Unprotected Spring  Protected Well  Unprotected Well  \
# 386                 0.1             0.5               0.0
# 387                 0.0             0.1               0.0
# 388                 0.1             0.3               0.0
# 389                 0.0             0.3               0.0
# 390                 0.1             0.1               0.1
# 391                 0.0             0.1               0.0
# 392                 0.0             0.3               0.0
# 393                 0.0             0.2               0.0
# 394                 0.0             0.3               0.0
# 395                 NaN             NaN               NaN
#
#      Borehole/ Tube well  Piped into dwelling  Piped to yard/ Plot  \
# 386                  1.6                 26.9                 28.6
# 387                  1.7                 34.8                 33.9
# 388                  1.3                 11.0                 20.6
# 389                  8.6                 26.2                 11.5
# 390                  0.5                 18.8                 21.6
# 391                  0.3                 10.1                 41.9
# 392                  5.6                 21.8                 39.8
# 393                  2.3                 27.4                 23.8
# 394                  2.5                 25.5                 28.3
# 395                  NaN                  NaN                  NaN
#
#      Bottled water  Rain/ Harvested water  Water Vendor  \
# 386            5.2                    0.0          10.2
# 387            5.5                    0.1           7.1
# 388            3.8                    0.1          16.1
# 389           18.7                    0.2          11.7
# 390            3.3                    0.2          28.1
# 391            0.8                    0.1          19.3
# 392            5.3                    1.8          14.6
# 393            9.2                    0.1          10.0
# 394           15.6                    0.1           6.4
# 395            NaN                    NaN           NaN
#
#      Public tap/ Standpipe  Not Stated
# 386                   25.9         0.1
# 387                   16.0         0.0
# 388                   45.1         0.0
# 389                   22.2         0.1
# 390                   27.0         0.0
# 391                   27.0         0.1
# 392                   10.2         0.1
# 393                   26.1         0.1
# 394                   19.8         0.0
# 395                    NaN         NaN

# %% [markdown]
# ### Solid Waste Disposal Data

# %%
df_waste=pd.read_csv(waste_link)
df_waste = df_waste.rename(columns={df_waste.columns[0]: 'Sub-county'})
#df_waste['Sub-county']=np.where(df_waste['Sub-county'].str.contains('LANGATA'), "LANG'ATA", df_waste['Sub-county'])

df_waste.tail(10)
# Out:
#     Sub-county Conventional Households  Main Sewer  Septic tank  Cess pool  \
# 385   EMBAKASI                 346,462        66.1         12.2        0.4
# 386  KAMUKUNJI                  83,680        74.0          8.2        1.7
# 387   KASARANI                 268,611        42.2         37.1        0.6
# 388      KIBRA                  61,651        37.0          5.4        0.3
# 389    LANGATA                  60,187        54.1         15.4        0.1
# 390   MAKADARA                  70,080        77.5          7.1        0.9
# 391    MATHARE                  74,967        73.8          6.9        0.5
# 392      NJIRU                 204,492        58.1         22.7        0.5
# 393    STAREHE                  66,108        63.3         12.4        0.8
# 394  WESTLANDS                 103,489        45.3         19.5        0.7
#
#      VIP Latrine  Pit latrine covered  Pit Latrine uncovered  Bucket latrine  \
# 385          4.3                 12.9                    1.6             2.1
# 386          2.7                  9.0                    0.9             2.9
# 387          5.3                 11.9                    2.1             0.6
# 388         11.8                 38.8                    4.7             0.9
# 389          7.1                 18.5                    3.3             0.2
# 390          2.7                  6.7                    0.7             4.0
# 391          5.3                  9.2                    2.1             1.8
# 392          5.7                 11.2                    1.0             0.3
# 393          6.4                 13.2                    2.2             1.5
# 394          8.6                 22.4                    2.4             0.6
#
#      Open/ Bush  Bio-septic tank/ Biodigester  Not Stated
# 385         0.1                           0.3         0.0
# 386         0.1                           0.4         0.1
# 387         0.0                           0.2         0.0
# 388         0.3                           0.8         0.0
# 389         0.3                           1.0         0.1
# 390         0.1                           0.3         0.0
# 391         0.1                           0.1         0.1
# 392         0.1                           0.3         0.1
# 393         0.1                           0.2         0.1
# 394         0.2                           0.5         0.0

# %% [markdown]
# ## Clean and Combine the data sets

# %%
#columns to be dropped
cols=['Nearest Town', 'Official Landline', 'Official Fax', 'Official Mobile', 'Official Email', 'Official Address',
      'Official Alternate No', 'Town', 'Post Code', 'County/ Sub-County', 'name']

# %%
#Create a wrangle function that will be used to clean the data
def wrangle(link):
  #read in the Health centre link
  data=pd.read_excel(link)
  #Filter data to retain data from Nairobi Province
  data=data[data['Province']=="Nairobi"]

  data['Division'] = data['Division'].fillna('UNKNOWN')
   # Extract the Subcouny from the Constituency Column, this will be used to join other data sets
  data['Sub-county'] = np.where(data['Constituency'].str.contains('DAGORETTI'), 'DAGORETTI',
                              np.where(data['Constituency'].str.contains('EMBAKASI') & (~data['Division'].str.contains('Njiru', na=False)), 'EMBAKASI',
                              np.where(data['Constituency'].str.contains('KASARANI') & (~data['Division'].str.contains('Njiru', na=False)), 'KASARANI',
                              np.where(data['Division'].str.contains("Njiru"), 'NJIRU',
                              np.where(data['Constituency'].str.contains("LANG'ATA"), 'LANGATA',
                              np.where(data['Constituency'].str.contains("ROYSAMBU"), 'KASARANI',
                              np.where(data['Constituency'].str.contains('RUARAKA'), 'KASARANI',
                              data['Constituency'])))))))

#Classify the Owner into broader groups
  data['Classification']=np.where(data['Owner'].str.contains('Private'),'Private',
                         np.where(data['Owner'].str.contains('Christian'), 'Faith Based Institution',
                         np.where(data['Owner'].str.contains('Supreme Council for Kenya Muslims'), 'Faith Based Institution',
                          np.where(data['Owner'].str.contains('Catholic Secretariat'), 'Faith Based Institution',
                          np.where(data['Owner'].str.contains('Humanitarian Agencies'), 'Non-Governmental Organizations',
                          np.where(data['Owner'].str.contains('State Coorporation'), 'Parastatal',
                           np.where(data['Owner'].str.contains('Faith Based'), 'Faith Based Institution', data['Owner']

  )))))))

#Merge the data set with Waste disposal data set
  data=data.merge(df_waste, left_on='Sub-county', right_on='Sub-county', how='left')

  #Merge with Water Data
  data=data.merge(df_water, left_on="Sub-county", right_on="County/ Sub-County", how='left')

  #Merge with People data
  data=data.merge(df_people, left_on='Sub-county', right_on='name', how='left')

  #drop columns that have only Nulls in the whole dataset
  data.dropna(axis=1, how='all', inplace=True)

  #drop address and Unnecessary columns
  for col in cols:
    data.drop(columns=col, inplace=True)

#Return the cleaned dataset
  return data
#Extract the Health data
df=wrangle(link_health_centres)
#print the size of the dataset
print(df.shape)
#Read in the first 5 rows
df.head(5)
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# (942, 56)
#    Facility Code                                Facility Name Province  \
# 0          19310   St Jude's Huruma Community Health Services  Nairobi
# 1          13043                        7Kr Mrs Health Centre  Nairobi
# 2          20346                      AAR Adams Health Centre  Nairobi
# 3          12861                       AAR City Centre Clinic  Nairobi
# 4          16796          AAR Clinic Sarit Centre (Westlands)  Nairobi
#
#     County   District   Division            Type  \
# 0  Nairobi    Mathare     Huruma  Medical Clinic
# 1  Nairobi    Langata   Lang'ata   Health Centre
# 2  Nairobi      Kibra     Woodly  Medical Clinic
# 3  Nairobi    Starehe    Starehe  Medical Clinic
# 4  Nairobi  Westlands  Parklands  Medical Clinic
#
#                                      Owner                   Location  \
# 0           Private Practice - Unspecified                     Huruma
# 1                             Armed Forces                  Mugumoini
# 2  Private Practice - General Practitioner                     Woodly
# 3         Private Enterprise (Institution)  Central Business District
# 4         Private Enterprise (Institution)                  Parklands
#
#       Sub Location                            Description of Location  \
# 0           Huruma  Situated near Ndururumo Primary School (Juja R...
# 1        Mugumoini         Next to Nairobi Opharnage,Off Lang'ata rd.
# 2           Woodly                         Greenhouse Adams 1st Floor
# 3              NaN  Stiuated at ICEA Building along Kenyatta Avenu...
# 4  Upper Parklands                          In Sarit Centre westlands
#
#   Constituency  Beds  Cots          In Charge     Job Title of in Charge  \
# 0      MATHARE   0.0   0.0   Caroline Achieng           Clinical Officer
# 1     LANG'ATA  14.0   0.0    Captain Murunga  Nursing Officer in Charge
# 2        KIBRA   0.0   0.0  Dr Mbuthia Wacera     Medical Superintendant
# 3      STAREHE   0.0   0.0     Dr. Alma Okudo           Doctor In Charge
# 4    WESTLANDS   0.0   0.0                NaN  Nursing Officer in Charge
#
#   Open 24 Hours Open Weekends Operational Status  ART C-IMCI   FP  HBC  IPD  \
# 0             N             Y        Operational  NaN    NaN  NaN  NaN  NaN
# 1             Y             Y        Operational  NaN      Y    Y    Y    Y
# 2             N             Y        Operational  NaN    NaN  NaN  NaN  NaN
# 3             N             Y        Operational  NaN    NaN    Y  NaN    Y
# 4             N             N        Operational  NaN    NaN  NaN  NaN  NaN
#
#   Sub-county Classification Conventional Households  Main Sewer  Septic tank  \
# 0    MATHARE        Private                  74,967        73.8          6.9
# 1    LANGATA   Armed Forces                  60,187        54.1         15.4
# 2      KIBRA        Private                  61,651        37.0          5.4
# 3    STAREHE        Private                  66,108        63.3         12.4
# 4  WESTLANDS        Private                 103,489        45.3         19.5
#
#    Cess pool  VIP Latrine  Pit latrine covered  Pit Latrine uncovered  \
# 0        0.5          5.3                  9.2                    2.1
# 1        0.1          7.1                 18.5                    3.3
# 2        0.3         11.8                 38.8                    4.7
# 3        0.8          6.4                 13.2                    2.2
# 4        0.7          8.6                 22.4                    2.4
#
#    Bucket latrine  Open/ Bush  Bio-septic tank/ Biodigester  Not Stated_x  \
# 0             1.8         0.1                           0.1           0.1
# 1             0.2         0.3                           1.0           0.1
# 2             0.9         0.3                           0.8           0.0
# 3             1.5         0.1                           0.2           0.1
# 4             0.6         0.2                           0.5           0.0
#
#    Pond Dam/ Lake  Stream/ River  Protected Spring  Unprotected Spring  \
# 0   0.0       0.0            0.0               0.3                 0.0
# 1   0.2       0.2            0.0               0.2                 0.0
# 2   0.0       0.0            0.0               1.4                 0.1
# 3   0.0       0.2            0.0               0.5                 0.0
# 4   0.0       0.2            0.1               1.1                 0.0
#
#    Protected Well  Unprotected Well  Borehole/ Tube well  Piped into dwelling  \
# 0             0.1               0.0                  0.3                 10.1
# 1             0.3               0.0                  8.6                 26.2
# 2             0.3               0.0                  1.3                 11.0
# 3             0.2               0.0                  2.3                 27.4
# 4             0.3               0.0                  2.5                 25.5
#
#    Piped to yard/ Plot  Bottled water  Rain/ Harvested water  Water Vendor  \
# 0                 41.9            0.8                    0.1          19.3
# 1                 11.5           18.7                    0.2          11.7
# 2                 20.6            3.8                    0.1          16.1
# 3                 23.8            9.2                    0.1          10.0
# 4                 28.3           15.6                    0.1           6.4
#
#    Public tap/ Standpipe  Not Stated_y    Male  Female  Intersex   Total
# 0                   27.0           0.1  106522  100028      14.0  206564
# 1                   22.2           0.1   96698  100774      17.0  197489
# 2                   45.1           0.0   94199   91569       9.0  185777
# 3                   26.1           0.1  109173  101238      12.0  210423
# 4                   19.8           0.0  153818  155021      15.0  308854

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 942 entries, 0 to 941
# Data columns (total 56 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Facility Code                 942 non-null    int64
#  1   Facility Name                 942 non-null    object
#  2   Province                      942 non-null    object
#  3   County                        942 non-null    object
#  4   District                      942 non-null    object
#  5   Division                      942 non-null    object
#  6   Type                          942 non-null    object
#  7   Owner                         942 non-null    object
#  8   Location                      894 non-null    object
#  9   Sub Location                  672 non-null    object
#  10  Description of Location       641 non-null    object
#  11  Constituency                  942 non-null    object
#  12  Beds                          942 non-null    float64
#  13  Cots                          942 non-null    float64
#  14  In Charge                     592 non-null    object
#  15  Job Title of in Charge        553 non-null    object
#  16  Open 24 Hours                 931 non-null    object
#  17  Open Weekends                 933 non-null    object
#  18  Operational Status            942 non-null    object
#  19  ART                           109 non-null    object
#  20  C-IMCI                        72 non-null     object
#  21  FP                            280 non-null    object
#  22  HBC                           250 non-null    object
#  23  IPD                           297 non-null    object
#  24  Sub-county                    942 non-null    object
#  25  Classification                942 non-null    object
#  26  Conventional Households       942 non-null    object
#  27  Main Sewer                    942 non-null    float64
#  28  Septic tank                   942 non-null    float64
#  29  Cess pool                     942 non-null    float64
#  30  VIP Latrine                   942 non-null    float64
#  31  Pit latrine covered           942 non-null    float64
#  32  Pit Latrine uncovered         942 non-null    float64
#  33  Bucket latrine                942 non-null    float64
#  34  Open/ Bush                    942 non-null    float64
#  35  Bio-septic tank/ Biodigester  942 non-null    float64
#  36  Not Stated_x                  942 non-null    float64
#  37  Pond                          942 non-null    float64
#  38  Dam/ Lake                     942 non-null    object
#  39  Stream/ River                 942 non-null    float64
#  40  Protected Spring              942 non-null    float64
#  41  Unprotected Spring            942 non-null    float64
#  42  Protected Well                942 non-null    float64
#  43  Unprotected Well              942 non-null    float64
#  44  Borehole/ Tube well           942 non-null    float64
#  45  Piped into dwelling           942 non-null    float64
#  46  Piped to yard/ Plot           942 non-null    float64
#  47  Bottled water                 942 non-null    float64
#  48  Rain/ Harvested water         942 non-null    float64
#  49  Water Vendor                  942 non-null    float64
#  50  Public tap/ Standpipe         942 non-null    float64
#  51  Not Stated_y                  942 non-null    float64
#  52  Male                          942 non-null    int64
#  53  Female                        942 non-null    int64
#  54  Intersex                      942 non-null    float64
#  55  Total                         942 non-null    int64
# dtypes: float64(27), int64(4), object(25)
# memory usage: 412.2+ KB

# %%
df['Sub-county'].value_counts()
# Out:
# Sub-county
# KASARANI     179
# EMBAKASI     149
# STAREHE      137
# DAGORETTI    105
# KIBRA         85
# WESTLANDS     72
# LANGATA       69
# KAMUKUNJI     59
# MAKADARA      55
# MATHARE       16
# NJIRU         16
# Name: count, dtype: int64

# %%
df['Classification'].value_counts()
# Out:
# Classification
# Private                           556
# Non-Governmental Organizations    119
# Faith Based Institution           101
# Local Authority                    58
# Ministry of Health                 56
# Other Public Institution           13
# Community                          11
# Parastatal                         10
# Armed Forces                        9
# Academic (if registered)            6
# Company Medical Service             3
# Name: count, dtype: int64

# %%
df['Operational Status'].value_counts()
# Out:
# Operational Status
# Operational        917
# Not-Operational     19
# Pending Opening      6
# Name: count, dtype: int64

# %%
df[df['Operational Status']=='Operational'].groupby('Sub-county')['Facility Code'].count().sort_values()
# Out:
# Sub-county
# MATHARE       16
# NJIRU         16
# MAKADARA      51
# KAMUKUNJI     59
# LANGATA       68
# WESTLANDS     71
# KIBRA         81
# DAGORETTI    105
# STAREHE      137
# EMBAKASI     142
# KASARANI     171
# Name: Facility Code, dtype: int64

# %% [markdown]
# - Health Centres Per Household/population
# - Health Centres dependednt on water and  Waste disposal
# - Number of beds and cots dependent on Population, sex
# - Availability of Government and NGO health Services in Lower In come Areas

# %%
df.to_csv('Combined_data2.csv')

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ###General Data

# %%
df.head(1)
# Out:
#    Facility Code                                Facility Name Province  \
# 0          19310   St Jude's Huruma Community Health Services  Nairobi
#
#     County District Division            Type                           Owner  \
# 0  Nairobi  Mathare   Huruma  Medical Clinic  Private Practice - Unspecified
#
#   Location Sub Location                            Description of Location  \
# 0   Huruma       Huruma  Situated near Ndururumo Primary School (Juja R...
#
#   Constituency  Beds  Cots         In Charge Job Title of in Charge  \
# 0      MATHARE   0.0   0.0  Caroline Achieng       Clinical Officer
#
#   Open 24 Hours Open Weekends Operational Status  ART C-IMCI   FP  HBC  IPD  \
# 0             N             Y        Operational  NaN    NaN  NaN  NaN  NaN
#
#   Sub-county Classification Conventional Households  Main Sewer  Septic tank  \
# 0    MATHARE        Private                  74,967        73.8          6.9
#
#    Cess pool  VIP Latrine  Pit latrine covered  Pit Latrine uncovered  \
# 0        0.5          5.3                  9.2                    2.1
#
#    Bucket latrine  Open/ Bush  Bio-septic tank/ Biodigester  Not Stated_x  \
# 0             1.8         0.1                           0.1           0.1
#
#    Pond Dam/ Lake  Stream/ River  Protected Spring  Unprotected Spring  \
# 0   0.0       0.0            0.0               0.3                 0.0
#
#    Protected Well  Unprotected Well  Borehole/ Tube well  Piped into dwelling  \
# 0             0.1               0.0                  0.3                 10.1
#
#    Piped to yard/ Plot  Bottled water  Rain/ Harvested water  Water Vendor  \
# 0                 41.9            0.8                    0.1          19.3
#
#    Public tap/ Standpipe  Not Stated_y    Male  Female  Intersex   Total
# 0                   27.0           0.1  106522  100028      14.0  206564

# %%
fig = px.pie(names=df['Operational Status'], title="Health Centres Operation Status in Nairobi")
fig.update_layout(title_x=0.5)
print(df['Operational Status'].value_counts())
fig.show()
# Out:
# Operational Status
# Operational        917
# Not-Operational     19
# Pending Opening      6
# Name: count, dtype: int64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c19bf180-a9d7-4cde-9285-e8328f773131" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
%{x}\u003cbr\u003eFacility Code=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"N","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"N","offsetgroup":"N","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Medical Clinic","Dispensary","VCT Centre (Stand-Alone)","Health Centre","Other Hospital","Laboratory (Stand-alone)","Medical Centre","Dental Clinic","Nursing Home","Health Programme","Health Project","Training Institution in Health (Stand-alone)","Maternity Home","Eye Centre","Eye Clinic","District Health Office","Radiology Unit"],"xaxis":"x","y":[366,172,53,45,16,13,11,9,8,4,3,3,2,2,1,1,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Open 24 Hours=Y\u003cbr\u003eType=%{x}\u003cbr\u003eFacility Code=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Y","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Y","offsetgroup":"Y","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Medical Clinic","Health Centre","Other Hospital","Nursing Home","Dispensary","Maternity Home","District Hospital","National Referral Hospital","Medical Centre","Sub-District Hospital","Training Institution in Health (Stand-alone)"],"xaxis":"x","y":[77,43,24,17,16,12,3,2,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888 ...

# %%
df_class=df_op.groupby('Classification').agg({
    'Facility Code':pd.Series.nunique
}).reset_index().sort_values(by='Facility Code',ascending=False)
fig=px.bar(df_class, x='Classification', y='Facility Code', title='Classification of Health Facilities in Nairobi', text_auto=True

)
fig.update_layout(yaxis_title='Number of Health Facility',  xaxis_title="Health Facilities Classisfication", title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2cb2be8b-01bc-4c61-9cf9-64a96bf58676" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2cb2be8b-01bc-4c61-9cf9-64a96bf58676")) {                    Plotly.newPlot(                        "2cb2be8b-01bc-4c61-9cf9-64a96bf58676",                        [{"alignmentgroup":"True","hovertemplate":"Classification=%{x}\u003cbr\u003eFacility Code=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Private","Non-Governmental Organizations","Faith Based Institution","Local Authority","Ministry of Health","Other Public Institution","Community","Armed Forces","Parastatal","Academic (if registered)","Company Medical Service"],"xaxis":"x","y":[546,114,96,57,53,13,11,9,9,6,3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color" ...

# %% [markdown]
# ###Sub County Data Visualization

# %%
sub_cl=df_op.groupby(['Sub-county', 'Classification']).agg({'Facility Code':pd.Series.nunique}).reset_index().sort_values(by='Facility Code', ascending=False)
sub_cl=sub_cl[sub_cl['Facility Code']>1]
fig=px.bar(sub_cl, x='Sub-county', y='Facility Code', color='Classification', title='Healthcare Facility Classification by Sub-County',
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4ce033cf-ca5b-4d72-9b2e-b9f0ce58218e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ce033cf-ca5b-4d72-9b2e-b9f0ce58218e")) {                    Plotly.newPlot(                        "4ce033cf-ca5b-4d72-9b2e-b9f0ce58218e",                        [{"alignmentgroup":"True","hovertemplate":"Classification=Private\u003cbr\u003eSub-county=%{x}\u003cbr\u003eFacility Code=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Private","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Private","offsetgroup":"Private","orientation":"v","showlegend":true,"textposition":"auto","x":["KASARANI","STAREHE","EMBAKASI","DAGORETTI","WESTLANDS","KAMUKUNJI","LANGATA","KIBRA","MAKADARA","NJIRU","MATHARE"],"xaxis":"x","y":[130,90,84,63,45,34,30,29,27,8,6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Classification=Faith Based Institution\u003cbr\u003eSub-county=%{x}\u003cbr\u003eFacility Code=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Faith Based Institution","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Faith Based Institution","offsetgroup":"Faith Based Institution","orientation":"v","showlegend":true,"textposition":"auto","x":["EMBAKASI","LANGATA","KASARANI","DAGORETTI","KAMUKUNJI","MAKADARA","KIBRA","MATHARE","STAREHE","WESTLANDS","NJIRU"],"xaxis":"x","y":[22,13,12,10,8,7,6,5,5,4,4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Classification=Ministry of Health\u003cbr\u003eSub-county=%{x}\u003cbr\u003eFacility Code=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ministry of Health","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Ministry of Health","offsetgroup":"Ministry of Health","orientation":"v","showlegend":true,"textposition":"auto","x":["KIBRA","KASARANI","EMBAKASI","LANGATA","DAGORETTI","MATHARE","WESTLANDS"],"xaxis":"x","y":[20,9,5,5,5,3,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Classification=Non-Governmental Organizations\u003cbr\u003eSub-county=%{x}\u003cbr\u003eFacility Code=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Non-Governmental Organizations","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Non-Governmental Organizations","offsetgroup":"Non-Governmental Organizations","orientation":"v","showlegend":true,"textposition":"auto","x":["KIBRA","DAGORETTI","EMBAKASI","STAREHE","WESTLANDS","LANGATA","KASARANI","KAMUKUNJI","MAKADARA","NJIRU"],"xaxis":"x","y":[17,17,16,16,11,9,9,9,6,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Classification=Local Authority\u003cbr\u003eSub-county=%{x}\u003cbr\u003eFacility Code=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Local Authority","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Local Authority","offsetgroup":"Local Authority","orientation":"v","showlegend":true,"textposition":"auto","x":["STAREHE","MAKADARA","EMBAKASI","KAMUKUNJI","KASARANI","WESTLANDS","DAGORETTI","LANGATA","KIBRA"],"xaxis":"x","y":[10,9,9,7,6,5,4,3,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Classification=Other Public Institution\u003cbr\u003eSub-county=%{x}\u003cbr\u003eFacility Code=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other Public Institution","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Other Public Institution","offsetgroup":"Other Public Institution","orientation":"v","showlegend":true,"textposition":"auto","x":["STAREHE","KASARANI","DAGORETTI"],"xaxis":"x","y":[8,2,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Classification=Community\u003cbr\u003eSub-county=%{x}\u003cbr\u003eFacility Code ...

# %%
#filter data to get only Operational Health Facilities

i=df_op.groupby(['Sub-county']).agg({'Facility Code':pd.Series.nunique}).reset_index().sort_values(by='Facility Code', ascending=False)

# Create the bar chart
fig = px.bar(i, x='Sub-county', y='Facility Code',title="Distribution of Operational Health Facilities per County",  text_auto=True)
fig.update_layout(xaxis_title="Sub-County", yaxis_title="Number of Health Facilities", )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e37d9a69-ed88-44c6-8584-bb0f2b114a85" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e37d9a69-ed88-44c6-8584-bb0f2b114a85")) {                    Plotly.newPlot(                        "e37d9a69-ed88-44c6-8584-bb0f2b114a85",                        [{"alignmentgroup":"True","hovertemplate":"Sub-county=%{x}\u003cbr\u003eFacility Code=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["KASARANI","EMBAKASI","STAREHE","DAGORETTI","KIBRA","WESTLANDS","LANGATA","KAMUKUNJI","MAKADARA","MATHARE","NJIRU"],"xaxis":"x","y":[171,142,137,105,81,71,68,59,51,16,16],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode ...

# %%
#filter data to get only Operational Health Facilities

i=df_op.groupby(['Sub-county', 'Open 24 Hours']).agg({'Facility Code':pd.Series.nunique}).reset_index().sort_values(by='Facility Code', ascending=False)

# Create the bar chart
fig = px.bar(i, x='Sub-county', y='Facility Code',color='Open 24 Hours',title="Distribution of Operational Health Facilities per County")
fig.update_layout(xaxis_title="Sub-County", yaxis_title="Number of Health Facilities", )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4779780a-075b-4340-ac58-ca131939bf51" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4779780a-075b-4340-ac58-ca131939bf51")) {                    Plotly.newPlot(                        "4779780a-075b-4340-ac58-ca131939bf51",                        [{"alignmentgroup":"True","hovertemplate":"Open 24 Hours=N\u003cbr\u003eSub-county=%{x}\u003cbr\u003eFacility Code=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"N","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"N","offsetgroup":"N","orientation":"v","showlegend":true,"textposition":"auto","x":["KASARANI","STAREHE","EMBAKASI","DAGORETTI","KIBRA","LANGATA","WESTLANDS","KAMUKUNJI","MAKADARA","NJIRU","MATHARE"],"xaxis":"x","y":[148,125,87,84,67,54,42,40,36,14,13],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Open 24 Hours=Y\u003cbr\u003eSub-county=%{x}\u003cbr\u003eFacility Code=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Y","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Y","offsetgroup":"Y","orientation":"v","showlegend":true,"textposition":"auto","x":["EMBAKASI","WESTLANDS","KASARANI","DAGORETTI","KAMUKUNJI","MAKADARA","LANGATA","KIBRA","STAREHE","MATHARE","NJIRU"],"xaxis":"x","y":[54,27,22,20,18,14,14,13,10,3,2],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888 ...

# %%
i=df_op.groupby(['Sub-county', 'Open Weekends']).agg({'Facility Code':pd.Series.nunique}).reset_index().sort_values(by='Facility Code', ascending=False)

# Create the bar chart
fig = px.bar(i, x='Sub-county', y='Facility Code',color='Open Weekends',title="Health Facilities Open on Weekends per Sub County")
fig.update_layout(xaxis_title="Sub-County", yaxis_title="Number of Health Facilities", )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="80450b77-7afb-48dc-8f76-d5d189c5bc97" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80450b77-7afb-48dc-8f76-d5d189c5bc97")) {                    Plotly.newPlot(                        "80450b77-7afb-48dc-8f76-d5d189c5bc97",                        [{"alignmentgroup":"True","hovertemplate":"Open Weekends=Y\u003cbr\u003eSub-county=%{x}\u003cbr\u003eFacility Code=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Y","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Y","offsetgroup":"Y","orientation":"v","showlegend":true,"textposition":"auto","x":["KASARANI","EMBAKASI","STAREHE","DAGORETTI","WESTLANDS","KIBRA","LANGATA","KAMUKUNJI","MAKADARA","NJIRU","MATHARE"],"xaxis":"x","y":[95,94,60,50,45,42,40,34,30,10,9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Open Weekends=N\u003cbr\u003eSub-county=%{x}\u003cbr\u003eFacility Code=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"N","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"N","offsetgroup":"N","orientation":"v","showlegend":true,"textposition":"auto","x":["STAREHE","KASARANI","DAGORETTI","EMBAKASI","KIBRA","LANGATA","WESTLANDS","KAMUKUNJI","MAKADARA","MATHARE","NJIRU"],"xaxis":"x","y":[75,75,55,47,38,28,25,24,20,7,6],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888888 ...

# %%
i=df_op.groupby('Sub-county').agg({
    'Total':np.mean,
    'Facility Code':pd.Series.nunique
}).reset_index()
i['People/facility']=i['Total']/i['Facility Code']
i.sort_values(by='People/facility', inplace=True, ascending=False)

fig=px.bar(i, x='Sub-county', y='People/facility', title='Distribution of people per facility', text_auto=True)
fig.update_layout(title_x=0.5, yaxis_title="People per Facility")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="48d099ed-786b-4e35-b1b1-2d53a1d39ff1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48d099ed-786b-4e35-b1b1-2d53a1d39ff1")) {                    Plotly.newPlot(                        "48d099ed-786b-4e35-b1b1-2d53a1d39ff1",                        [{"alignmentgroup":"True","hovertemplate":"Sub-county=%{x}\u003cbr\u003ePeople\u002ffacility=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["NJIRU","MATHARE","EMBAKASI","KASARANI","KAMUKUNJI","WESTLANDS","DAGORETTI","MAKADARA","LANGATA","KIBRA","STAREHE"],"xaxis":"x","y":[39155.125,12910.25,6963.43661971831,4565.2397660818715,4547.050847457627,4350.056338028169,4135.314285714286,3716.392156862745,2904.25,2293.543209876543,1535.934306569343],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""} ...

# %%
i=df_op.groupby('Sub-county').agg({
    'Total':np.mean,
    'Beds':np.sum,
    'Cots':np.sum
}).reset_index()
i['Population/beds']=i['Total']/i['Beds']
i=i.sort_values(by='Population/beds', ascending=False)
f=px.bar(i, x='Sub-county', y='Population/beds', text_auto=True,title="Population-to-Bed Ratio")
f.show()
i
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e15d1069-93ad-4ea9-9ed9-4d01cbd45552" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e15d1069-93ad-4ea9-9ed9-4d01cbd45552")) {                    Plotly.newPlot(                        "e15d1069-93ad-4ea9-9ed9-4d01cbd45552",                        [{"alignmentgroup":"True","hovertemplate":"Sub-county=%{x}\u003cbr\u003ePopulation\u002fbeds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["NJIRU","KASARANI","EMBAKASI","MAKADARA","DAGORETTI","STAREHE","WESTLANDS","MATHARE","LANGATA","KAMUKUNJI","KIBRA"],"xaxis":"x","y":[24095.46153846154,2070.7055702917773,1356.3895747599452,971.9794871794871,693.6230031948882,589.4201680672269,487.9210110584518,282.96438356164384,264.730563002681,247.71560480147738,104.13508968609865],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar ...
#    Sub-county     Total    Beds   Cots  Population/beds
# 8       NJIRU  626482.0    26.0    3.0     24095.461538
# 3    KASARANI  780656.0   377.0   53.0      2070.705570
# 1    EMBAKASI  988808.0   729.0  142.0      1356.389575
# 6    MAKADARA  189536.0   195.0   19.0       971.979487
# 0   DAGORETTI  434208.0   626.0  112.0       693.623003
# 9     STAREHE  210423.0   357.0   58.0       589.420168
# 10  WESTLANDS  308854.0   633.0   32.0       487.921011
# 7     MATHARE  206564.0   730.0    0.0       282.964384
# 5     LANGATA  197489.0   746.0    0.0       264.730563
# 2   KAMUKUNJI  268276.0  1083.0  206.0       247.715605
# 4       KIBRA  185777.0  1784.0  441.0       104.135090

# %% [markdown]
# ### Maternal Health

# %%
df_mat=df_op[df_op['Type']=='Maternity Home']
maternal=df_mat.groupby(['Sub-county','Classification']).agg({
    'Facility Code':pd.Series.nunique,
    'Beds':np.sum,
    'Cots':np.sum
}).reset_index()
print(maternal.shape)
m=px.pie(maternal, names='Classification', title="Maternity Facilities")
m.update_layout(title_x=0.5 )

m.show()
# Out:
# (9, 5)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="86f3d945-6f6f-4c76-bcb7-c6066eb1c4ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86f3d945-6f6f-4c76-bcb7-c6066eb1c4ea")) {                    Plotly.newPlot(                        "86f3d945-6f6f-4c76-bcb7-c6066eb1c4ea",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Classification=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Private","Private","Private","Community","Private","Non-Governmental Organizations","Private","Non-Governmental Organizations","Private"],"legendgroup":"","name":"","showlegend":true,"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar ...

# %%
fig=px.bar(maternal.sort_values(by='Facility Code', ascending=False), x="Sub-county", y="Facility Code",
           title='Maternity Facilities per Sub_County', text_auto=True
          )
fig.update_layout(yaxis_title='No. of Facilities')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="eeda5589-ea05-431a-8c35-1ec9ad53f426" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eeda5589-ea05-431a-8c35-1ec9ad53f426")) {                    Plotly.newPlot(                        "eeda5589-ea05-431a-8c35-1ec9ad53f426",                        [{"alignmentgroup":"True","hovertemplate":"Sub-county=%{x}\u003cbr\u003eFacility Code=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["KIBRA","EMBAKASI","LANGATA","KAMUKUNJI","KASARANI","KIBRA","LANGATA","MAKADARA","WESTLANDS"],"xaxis":"x","y":[4,2,2,1,1,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"t ...

# %%
m=maternal.groupby('Sub-county')[['Beds', 'Cots']].sum().reset_index()
m
# Out:
#   Sub-county  Beds  Cots
# 0   EMBAKASI  32.0   6.0
# 1  KAMUKUNJI   6.0   0.0
# 2   KASARANI  60.0  12.0
# 3      KIBRA  46.0   4.0
# 4    LANGATA  43.0   0.0
# 5   MAKADARA  12.0   0.0
# 6  WESTLANDS   6.0   1.0

# %% [markdown]
# ## Waste Disposal

# %%
df_waste.head()
# Out:
#   Sub-county Conventional Households  Main Sewer  Septic tank  Cess pool  \
# 0      KENYA              12,043,016         9.7          9.2        0.3
# 1      Rural               7,379,282         0.3          1.7        0.1
# 2      Urban               4,663,734        24.6         21.1        0.6
# 3    MOMBASA                 376,295        16.6         31.2        1.1
# 4  CHANGAMWE                  46,439        27.3         25.9        1.4
#
#    VIP Latrine  Pit latrine covered  Pit Latrine uncovered  Bucket latrine  \
# 0         11.9                 51.2                    9.4             0.8
# 1         11.5                 61.7                   12.5             0.5
# 2         12.5                 34.4                    4.4             1.2
# 3         11.1                 30.8                    5.5             2.4
# 4         10.2                 28.1                    4.3             2.6
#
#    Open/ Bush  Bio-septic tank/ Biodigester  Not Stated
# 0         7.4                           0.2         0.0
# 1        11.5                           0.1         0.0
# 2         0.8                           0.3         0.0
# 3         0.9                           0.3         0.0
# 4         0.2                           0.1         0.0

# %%
col=['Cess pool', 'Pit Latrine uncovered', 'Bucket latrine', 'Open/ Bush']
df['Disposal_of_waste']=df['Cess pool']+df['Pit Latrine uncovered']+df['Bucket latrine']+df['Open/ Bush']
d=df.groupby('Sub-county')['Disposal_of_waste'].mean().sort_values()
d.plot(kind='barh', xlabel='% of Unhealthy Waste Disposal', title="Unhealthy Solid Waste Disposal" );

# %% [markdown]
# ###Water Sources

# %%
df_water.head()
# Out:
#   County/ Sub-County  Pond Dam/ Lake  Stream/ River  Protected Spring  \
# 0              KENYA   1.6       3.3           16.8               7.1
# 1              Rural   2.4       4.9           25.8              10.5
# 2              Urban   0.2       0.8            2.6               1.8
# 3            MOMBASA   0.1       0.2            0.1               1.2
# 4          CHANGAMWE   0.0       0.0            0.1               0.8
#
#    Unprotected Spring  Protected Well  Unprotected Well  Borehole/ Tube well  \
# 0                 2.4             7.0               2.6                  9.9
# 1                 3.7             9.0               4.0                 11.8
# 2                 0.3             4.0               0.5                  6.8
# 3                 0.1             4.6               0.4                  5.2
# 4                 0.1             1.2               0.1                  1.2
#
#    Piped into dwelling  Piped to yard/ Plot  Bottled water  \
# 0                 10.1                 14.1            2.8
# 1                  5.1                  7.8            0.3
# 2                 18.1                 23.9            6.7
# 3                  7.2                  5.2           11.4
# 4                  4.0                  4.2            5.2
#
#    Rain/ Harvested water  Water Vendor  Public tap/ Standpipe  Not Stated
# 0                    3.9           8.5                    9.9         0.0
# 1                    5.0           3.3                    6.4         0.0
# 2                    2.0          16.7                   15.6         0.0
# 3                    0.3          43.5                   20.5         0.0
# 4                    0.1          59.9                   23.3         0.0

# %%
df_water.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396 entries, 0 to 395
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   County/ Sub-County     395 non-null    object
#  1   Pond                   384 non-null    float64
#  2   Dam/ Lake              385 non-null    object
#  3   Stream/ River          388 non-null    float64
#  4   Protected Spring       387 non-null    float64
#  5   Unprotected Spring     385 non-null    float64
#  6   Protected Well         383 non-null    float64
#  7   Unprotected Well       386 non-null    float64
#  8   Borehole/ Tube well    385 non-null    float64
#  9   Piped into dwelling    391 non-null    float64
#  10  Piped to yard/ Plot    391 non-null    float64
#  11  Bottled water          383 non-null    float64
#  12  Rain/ Harvested water  386 non-null    float64
#  13  Water Vendor           383 non-null    float64
#  14  Public tap/ Standpipe  385 non-null    float64
#  15  Not Stated             350 non-null    float64
# dtypes: float64(14), object(2)
# memory usage: 49.6+ KB

# %%
df['water_sources']=df['Pond']+df["Stream/ River"]+df['Unprotected Spring']+df['Unprotected Well']+df['Water Vendor']+df['Public tap/ Standpipe']
water=df.groupby('Sub-county')['water_sources'].mean().sort_values()
water.plot(kind='barh', ylabel='Sub_County',
           xlabel='% of Reliance of easily Contaminated Water', title="Proportion of People Relying on easily Contaminated Water");
